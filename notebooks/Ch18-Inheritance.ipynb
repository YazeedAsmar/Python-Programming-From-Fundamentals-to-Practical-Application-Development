# %% [markdown]
# # Inheritance
# <a href="https://colab.research.google.com/github/rambasnet/Python-Fundamentals/blob/master/notebooks/Ch18-Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# - http://openbookproject.net/thinkcs/python/english3e/inheritance.html
# - https://www.python-course.eu/python3_inheritance.php
#
# - powerful feature that facilitates code reuse mimicking real-world phenomena
# - ability to define a new class (child) that is modified version of an existing class (parent)
# - can add new methods and properties to a class without modifying the existing class
# ```
# class childClassName(parentClass1, baseClass2, ...):
#     #code (attributes and methods)
#     pass
# ```

# %% [markdown]
# ## Single Inheritance
# - supported by almost all OOP langauges
# <img src="https://github.com/Mohamad-Selawy/Python-Fundamentals/blob/main/notebooks/resources/Inheritance.png?raw=1" width="100%">

# %%
# by dafault all python class implicitly inherit from object base class
class A(object):
    def __init__(self):
        self.a = "A"

    def printMe(self):
        print("A's printMe called!")
        print('a = {}'.format(self.a))

    def sayHi(self):
        print('{} says HI!'.format(self.a))

# %%
obja = A()
obja.printMe()
obja.sayHi()
# Out:
# A's printMe called!
# a = A
# A says HI!

# %%
# single inheritance
class B(A):
    def __init__(self):
        # must explictly invoke base classes constructors
        # to inherit properties/attributes
        #A.__init__(self) # try commenting this out
        self.b = 'B'

    def update(self):
        print("Attributes before modifaction: {} and {}".format(self.a, self.b))
        self.a = 'AAA' #can modify inherited attributes
        print("Attributes after modification: {} and {}".format(self.a, self.b))

    # overrides inherited printMe
    def printMe(self):
        print("B's printMe called")
        print('a = {}'.format(self.a))

# %%
objb = B()
# shows that A's properties are inherited by B
objb.update()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/1312489048.py in <cell line: 0>()
#       1 objb = B()
#       2 # shows that A's properties are inherited by B
# ----> 3 objb.update()
#
# /tmp/ipykernel_3211/1596476040.py in update(self)
#       8
#       9     def update(self):
# ---> 10         print("Attributes before modifaction: {} and {}".format(self.a, self.b))
#      11         self.a = 'AAA' #can modify inherited attributes
#      12         print("Attributes after modification: {} and {}".format(self.a, self.b))
#
# AttributeError: 'B' object has no attribute 'a'

# %%
# object a's properties are independent from object b's properties
print("obja's property a = {}".format(obja.a))
print("objb's property a = {}".format(objb.a))
# Out:
# obja's property a = A
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/1308486093.py in <cell line: 0>()
#       1 # object a's properties are independent from object b's properties
#       2 print("obja's property a = {}".format(obja.a))
# ----> 3 print("objb's property a = {}".format(objb.a))
#
# AttributeError: 'B' object has no attribute 'a'

# %%
# B inherits A's sayHi()
# what is the output of the following?
objb.sayHi()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/1749312439.py in <cell line: 0>()
#       1 # B inherits A's sayHi()
#       2 # what is the output of the following?
# ----> 3 objb.sayHi()
#
# /tmp/ipykernel_3211/949562657.py in sayHi(self)
#       9
#      10     def sayHi(self):
# ---> 11         print('{} says HI!'.format(self.a))
#
# AttributeError: 'B' object has no attribute 'a'

# %% [markdown]
# ## Overriding
# - child class can redefine method that are inherited from parent class with the same name
# - e.g., printMe() method in class B overrides A's printMe
# - A's printme can still be called
#     - syntax
#     ```
#     ClassName.method(object)
#     ```

# %%
objb.printMe()
# Out:
# B's printMe called
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/581139490.py in <cell line: 0>()
# ----> 1 objb.printMe()
#
# /tmp/ipykernel_3211/1596476040.py in printMe(self)
#      15     def printMe(self):
#      16         print("B's printMe called")
# ---> 17         print('a = {}'.format(self.a))
#
# AttributeError: 'B' object has no attribute 'a'

# %%
A.printMe(obja)
# Out:
# A's printMe called!
# a = A

# %%
A.printMe(objb)
# Out:
# A's printMe called!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/3977030366.py in <cell line: 0>()
# ----> 1 A.printMe(objb)
#
# /tmp/ipykernel_3211/949562657.py in printMe(self)
#       6     def printMe(self):
#       7         print("A's printMe called!")
# ----> 8         print('a = {}'.format(self.a))
#       9
#      10     def sayHi(self):
#
# AttributeError: 'B' object has no attribute 'a'

# %%
# C inherits from B which inherits from A
class C(B):
    def __init__(self):
        B.__init__(self)
        self.c = 'C'

    def printMe(self):
        print("C's printMe called:")
        print("Attributes are {}, {}, {}".format(self.c, self.b, self.a))

# %%
c1 = C()
c1.printMe()
# Out:
# C's printMe called:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/241926923.py in <cell line: 0>()
#       1 c1 = C()
# ----> 2 c1.printMe()
#
# /tmp/ipykernel_3211/1912106273.py in printMe(self)
#       7     def printMe(self):
#       8         print("C's printMe called:")
# ----> 9         print("Attributes are {}, {}, {}".format(self.c, self.b, self.a))
#      10
#
# AttributeError: 'C' object has no attribute 'a'

# %%
# sayHi() inherited from A
c1.sayHi()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/1158629671.py in <cell line: 0>()
#       1 # sayHi() inherited from A
# ----> 2 c1.sayHi()
#
# /tmp/ipykernel_3211/949562657.py in sayHi(self)
#       9
#      10     def sayHi(self):
# ---> 11         print('{} says HI!'.format(self.a))
#
# AttributeError: 'C' object has no attribute 'a'

# %%
c1.update()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3211/1031084644.py in <cell line: 0>()
# ----> 1 c1.update()
#
# /tmp/ipykernel_3211/1596476040.py in update(self)
#       8
#       9     def update(self):
# ---> 10         print("Attributes before modifaction: {} and {}".format(self.a, self.b))
#      11         self.a = 'AAA' #can modify inherited attributes
#      12         print("Attributes after modification: {} and {}".format(self.a, self.b))
#
# AttributeError: 'C' object has no attribute 'a'

# %% [markdown]
# ## Multiple Inheritance
# - Python allows a class to derive/inherit from multiple base classes
#     - similar to C++
# - Java doesn't allow it (it's messy!)
# <img src="https://github.com/Mohamad-Selawy/Python-Fundamentals/blob/main/notebooks/resources/MultipleInheritance.png?raw=1" width="75%">

# %%
# not required to explictly inherit from object class
class D:
    def __init__(self):
        self.a = 'AAAAA'
        self.d = 'D'

    def scream(self):
        print("D's scream() called:")

# class E inherits from class C and D
class E(C, D):
    def __init__(self):
        # the order in which the base constructors are called matters!
        # same attributes of proior constructors are overridden by later constructors
        # e.g., try switching D and C's construntor calls
        D.__init__(self)
        C.__init__(self)
        self.e = 'E'

    def printMe(self):
        print("E's printMe called:")
        print("Attributes are {}, {}, {}, {}, {}".format(self.e, self.d, self.c, self.b, self.a))

# %%
e1 = E()
e1.printMe()
# Out:
# E's printMe called:
# Attributes are E, D, C, B, AAAAA

# %%
e1.scream()
# Out:
# D's scream() called:

# %%
e1.sayHi()
# Out:
# AAAAA says HI!

# %% [markdown]
# ## abc module - Abstract Base Classes and abstract methods
# - allows to define ABCs with abstract methods @abstractmethod decorators
# - an abstract class is a class that contains at least one **abstract method**
# - an **abstract method** is a method that is declared, but not implemented
# - these are base classes that must be extended/derived from and can't be instantiated
#     - derived/children classes implment the details of the methods

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    def __init__(self):
        pass

    @abstractmethod
    def area(self):
        pass

    def sayHi(self):
        print('hello from Shape ABC')

# %%
# can't instantiate an abstract class
a = Shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3211/3852130175.py in <cell line: 0>()
#       1 # can't instantiate an abstract class
# ----> 2 a = Shape()
#
# TypeError: Can't instantiate abstract class Shape without an implementation for abstract method 'area'

# %%
a.area()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3211/3969111684.py in <cell line: 0>()
# ----> 1 a.area()
#
# NameError: name 'a' is not defined

# %%
class Rectangle(Shape):
    def __init__(self, length=5, wid=5):
        Shape.__init__(self)
        self.length = length
        self.width = wid

    # uncomment area function to implement it in this derived class

    def area(self):
        return self.length * self.width

# %%
r = Rectangle()

# %%
r.area()
# Out:
# 25

# %%
r.sayHi()
# Out:
# hello from Shape ABC

# %% [markdown]
# # New ABC Class For Animal

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass

    @abstractmethod
    def move(self):
        pass

    def sleep(self):
        print("Sleeping...")

# %% [markdown]
# # Dog Class

# %%
class Dog(Animal):

    def __init__(self, name='Animal'):
        self.name = name

    def make_sound(self):
        print("Woof")

    def move(self):
        print("Running")


dog = Dog('Rex')
dog.make_sound()   # Woof
dog.move()         # Running
dog.sleep()        # Sleeping...
print('Dog name is :',dog.name) # Rex
# Out:
# Woof
# Running
# Sleeping...
# Dog name is : Rex

# %% [markdown]
# # Cat Class

# %%
class Cat(Animal):

    def __init__(self, name='Animal'):
        self.name = name

    def make_sound(self):
        print("Meow")

    def move(self):
        print("Prowling")


cat = Cat('Whiskers')
cat.make_sound()   # Meow
cat.move()         # Prowling
cat.sleep()        # Sleeping...
print('Cat name is :', cat.name) # Whiskers
# Out:
# Meow
# Prowling
# Sleeping...
# Cat name is : Whiskers

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1: `Vehicle` and `Car`/`Truck` Inheritance (Abstract Base Classes)
#
# This exercise focuses on demonstrating **inheritance** using an Abstract Base Class (`Vehicle`) and concrete subclasses (`Car` and `Truck`).
#
# Follow these steps to complete the exercise:
#
# 1.  **Define an Abstract Base Class `Vehicle`**:
#     *   Create a class named `Vehicle` that inherits from `abc.ABC`.
#     *   Declare two `abstractmethod`s within `Vehicle`: `start()` and `stop()`. These methods should not have implementations in the `Vehicle` class.
#
# 2.  **Define a Concrete Class `Car`**:
#     *   Create a class named `Car` that inherits from `Vehicle`.
#     *   Implement the `start()` method for `Car` to print a message like "Car engine started."
#     *   Implement the `stop()` method for `Car` to print a message like "Car engine stopped."
#     *   Add a new concrete method `drive()` to the `Car` class that prints "Car is driving."
#
# 3.  **Define a Concrete Class `Truck`**:
#     *   Create a class named `Truck` that also inherits from `Vehicle`.
#     *   Implement the `start()` method for `Truck` to print a message like "Truck engine started."
#     *   Implement the `stop()` method for `Truck` to print a message like "Truck engine stopped."
#     *   Add a new concrete method `load_cargo(weight)` to the `Truck` class. This method should take a `weight` argument and print a message indicating that the truck is loading cargo of that `weight`.
#
# 4.  **Demonstrate Usage**:
#     *   Instantiate an object of the `Car` class.
#     *   Call its `start()`, `drive()`, and `stop()` methods.
#     *   Instantiate an object of the `Truck` class.
#     *   Call its `start()`, `load_cargo()` (with an example weight), and `stop()` methods.

# %% [markdown]
# ##  Exercise2: Hospital Management System (Inheritance)
#
# ###  Scenario
#
# YouYou are asked to design a simple Hospital Management System. The system manages different types of people working in a hospital and their relationships.
#
# The hospital has:
#
# *   **Doctors**
# *   **Patients**
#
# All of them are people, but each has different roles and behaviors.
#
# ###  Requirements
#
# 1.  **Create a base class: `Person` (Parent Class)**
#     *   **Attributes**: `name`, `age`, `gender`, `id`
#     *   **Methods**: `display_info()` → prints all personal details.
#
# 2.  **Create a class: `Staff` (inherits from `Person`)**
#     *   **Additional Attributes**: `salary`, `department`
#     *   **Methods**: `work()` → prints "Staff is working in the hospital".
#
# 3.  **Create a class: `Doctor` (inherits from `Staff`)**
#     *   **Additional Attributes**: `specialization`, `patients_list` (a list to store names of patients).
#     *   **Methods**:
#         *   `diagnose(patient_name)` → prints that doctor is diagnosing a patient.
#         *   `add_patient(patient_name)` → adds the patient's name to the `patients_list`.
#         *   **Override** `work()` → prints "Doctor is treating patients".
#
# 5.  **Create a class: `Patient` (inherits from `Person`)**
#     *   **Additional Attributes**: `disease`, `room_number`.
#     *   **Methods**: `get_treatment()` → prints "Patient is receiving treatment".
#
# ###  Relationships
#
# *   A `Doctor` has many `Patient`s (through the `patients_list`).
# *   All classes (`Staff`, `Doctor`, `Patient`) inherit from `Person`.
#
# ###  Student Tasks
#
# **Task 1: Implement the Classes**
#
# *   Create all the classes (`Person`, `Staff`, `Doctor`, `Patient`) with their correct inheritance, attributes, and methods as described above.
#
# **Task 2: Create Objects**
#
# *   Create one `Doctor` object.
# *   Create two `Patient` objects.
#
# **Task 3: Demonstrate Functionality**
#
# *   Assign the two patients to the doctor using the `add_patient()` method.
# *   Call the `diagnose()` method for each patient (by passing their names) using the `Doctor` object.
# *   Call the `work()` method for the `Doctor` object.
# *   Call the `get_treatment()` method for each `Patient` object.
# *   Display all available information for every created object using their `display_info()` method.
